# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/wm811k-wafer-map/LSWMD.pkl

# %%
import imgaug as ia
import imgaug.augmenters as iaa
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
df = pd.read_pickle('../input/wm811k-wafer-map/LSWMD.pkl')

# %%
from tensorflow.keras.layers import Input, Conv2D, Dense, MaxPool2D, BatchNormalization
from tensorflow.keras.layers import Flatten, Softmax, Add
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Define the Residual Block
from tensorflow.keras.layers import Conv2D, BatchNormalization, Add, Activation

def residual_block(x, filters, kernel_size, strides=(1, 1)):
    y = Conv2D(filters, kernel_size, strides=strides, padding='same')(x)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    
    y = Conv2D(filters, kernel_size, padding='same')(y)
    y = BatchNormalization()(y)
    
    # Adjust the shape of the input tensor if needed
    if strides != (1, 1) or x.shape[-1] != filters:
        x = Conv2D(filters, (1, 1), strides=strides, padding='same')(x)
    
    y = Add()([x, y])
    y = Activation('relu')(y)
    return y


# Define the input layer
inputs = Input(shape=(224, 224, 3))

# Initial convolutional layer
x = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

# Residual blocks
x = residual_block(x, 16, (3, 3))
x = MaxPool2D(pool_size=(2, 2))(x)
x = residual_block(x, 32, (3, 3))
x = MaxPool2D(pool_size=(2, 2))(x)
x = residual_block(x, 64, (3, 3))
x = MaxPool2D(pool_size=(2, 2))(x)
x = residual_block(x, 128, (2, 2))
x = MaxPool2D(pool_size=(2, 2))(x)

# Additional layers
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
outputs = Dense(9, activation='softmax')(x)

# Define the model
model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 224, 224,  │        448 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 224, 224,  │         64 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 224, 224,  │      2,320 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 224, 224,  │         64 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 224, 224,  │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 224, 224,  │         64 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 224, 224,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 112, 112,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 112, 112,  │      4,640 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 112, 112,  │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 112, 112,  │        544 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 112, 112,  │          0 │ conv2d_11[0][0],  │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 112, 112,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 56, 56,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 56, 56,    │     18,496 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 56, 56,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 56, 56,    │      2,112 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 56, 56,    │          0 │ conv2d_14[0][0],  │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 56, 56,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 28, 28,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 28, 28,    │     32,896 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 28, 28,    │     65,664 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 28, 28,    │      8,320 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 28, 28,    │          0 │ conv2d_17[0][0],  │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 28, 28,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 14, 14,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 25088)     │          0 │ max_pooling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │ 12,845,568 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 9)         │      4,617 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,036,105 (49.73 MB)
#  Trainable params: 13,035,113 (49.73 MB)
#  Non-trainable params: 992 (3.88 KB)

# %%
import cv2

def reshape_images(images, height, width):
    reshaped_images = np.zeros((len(images), height, width, 3))
    for n in range(len(images)):
        for h in range(height):
            for w in range(width):
                reshaped_images[n, h, w, images[n][h][w]] = 1
    return reshaped_images

def augment_images(images, number=None):
    seq = iaa.Sequential([
        iaa.Fliplr(0.5),
        iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.05, 0.05), "y": (-0.05, 0.05)},
            rotate=(-180, 180),
            shear=(-8, 8)
        ),
    ], random_order=True)
    
    images_input = np.random.choice(images, number) if number else images
    images_expanded = []
    for image in images_input:
        images_expanded.append(image)
    images_expanded = np.array(images_expanded)
    images_augmented = seq(images=images_expanded)
    return images_augmented

# %%
import gc
gc.collect()
# Out:
# 327

# %%
df['failureNum']=df.failureType
df['trainTestNum']=df.trianTestLabel

mapping_type={
    'Center':0,
    'Donut':1,
    'Edge-Loc':2,
    'Edge-Ring':3,
    'Loc':4,
    'Random':5,
    'Scratch':6,
    'Near-full':7,
    'none':8}
mapping_traintest={'Training':0,'Test':1}
df=df.replace({'failureNum':mapping_type, 'trainTestNum':mapping_traintest})

# %%
df_label = df[(df['failureNum']>=0) & (df['failureNum']<=8)]
df_label = df_label.reset_index()
df_pattern = df[(df['failureNum']>=0) & (df['failureNum']<=7)]
df_pattern = df_pattern.reset_index()
df_none = df[(df['failureNum']==8)]

df_label.shape[0], df_pattern.shape[0], df_none.shape[0]
# Out:
# (172950, 25519, 147431)

# %%
class_num = 9
dsize = (224, 224)
count_per_class_test = 20
count_per_class = 80

x_test, y_test = [], []
for failureNum in range(class_num):
    extracted = df_label[df_label['failureNum'] == failureNum].sample(count_per_class_test, replace=True).waferMap
    resized = extracted.apply(lambda x:cv2.resize(x, dsize=dsize, interpolation=cv2.INTER_AREA))
    del extracted
    augmented = np.array(augment_images(resized))
    reshaped = reshape_images(augmented, dsize[1], dsize[0])
    del augmented

    labels = np.zeros((count_per_class_test, class_num))
    for i in range(count_per_class_test):
        labels[i][failureNum] = 1
        
    x_test.extend(reshaped)
    y_test.extend(labels)
x_test = np.array(x_test)
y_test = np.array(y_test)

histories = []
for j in range(100):
    x_train, y_train = [], []
    for failureNum in range(class_num):
        extracted = df_label[df_label['failureNum'] == failureNum].sample(count_per_class, replace=True).waferMap
        resized = extracted.apply(lambda x:cv2.resize(x, dsize=dsize, interpolation=cv2.INTER_AREA))
        del extracted
        augmented = np.array(augment_images(resized))
        reshaped = reshape_images(augmented, dsize[1], dsize[0])
        del augmented

        labels = np.zeros((count_per_class, class_num))
        for i in range(count_per_class):
            labels[i][failureNum] = 1

        x_train.extend(reshaped)
        y_train.extend(labels)
#     x_train, x_test, y_train, y_test = train_test_split(np.array(x), np.array(y), test_size=0.3)
    
    history = model.fit(np.array(x_train), np.array(y_train), validation_data=(x_test, y_test), epochs=20, batch_size=100)
    histories.append(history)
# Out:
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 18s/step - accuracy: 0.1099 - loss: 75.5102 - val_accuracy: 0.1222 - val_loss: 6.2699
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 106s 13s/step - accuracy: 0.1264 - loss: 26.0070 - val_accuracy: 0.1111 - val_loss: 13.0436
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 109s 13s/step - accuracy: 0.2498 - loss: 3.7916 - val_accuracy: 0.1389 - val_loss: 10.1928
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 13s/step - accuracy: 0.2504 - loss: 1.9751 - val_accuracy: 0.1333 - val_loss: 2.7019
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.4263 - loss: 1.6190 - val_accuracy: 0.1500 - val_loss: 2.2236
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 18s/step - accuracy: 0.5184 - loss: 1.3259 - val_accuracy: 0.1444 - val_loss: 2.6346
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 105s 13s/step - accuracy: 0.6232 - loss: 1.1355 - val_accuracy: 0.1444 - val_loss: 2.7811
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.6762 - loss: 0.9886 - val_accuracy: 0.1667 - val_loss: 2.8085
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.6946 - loss: 0.8981 - val_accuracy: 0.1444 - val_loss: 2.9284
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.7515 - loss: 0.7983 - val_accuracy: 0.1500 - val_loss: 2.8166
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 172s 17s/step - accuracy: 0.7554 - loss: 0.7366 - val_accuracy: 0.1944 - val_loss: 2.7025
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 113s 13s/step - accuracy: 0.7881 - loss: 0.6599 - val_accuracy: 0.1333 - val_loss: 3.0019
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.8335 - loss: 0.5859 - val_accuracy: 0.1722 - val_loss: 2.7810
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.8358 - loss: 0.5228 - val_accuracy: 0.1222 - val_loss: 2.9776
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.8512 - loss: 0.4860 - val_accuracy: 0.2000 - val_loss: 2.7725
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 146s 13s/step - accuracy: 0.8349 - loss: 0.4662 - val_accuracy: 0.1611 - val_loss: 2.7859
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 105s 13s/step - accuracy: 0.8934 - loss: 0.3836 - val_accuracy: 0.1889 - val_loss: 2.7728
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9270 - loss: 0.3238 - val_accuracy: 0.2278 - val_loss: 2.6181
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9098 - loss: 0.3381 - val_accuracy: 0.1889 - val_loss: 2.7004
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9464 - loss: 0.2694 - val_accuracy: 0.2111 - val_loss: 2.6915
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 16s/step - accuracy: 0.6175 - loss: 1.0391 - val_accuracy: 0.2611 - val_loss: 2.4817
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 114s 14s/step - accuracy: 0.6757 - loss: 0.8200 - val_accuracy: 0.2667 - val_loss: 2.2225
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.7405 - loss: 0.7141 - val_accuracy: 0.2444 - val_loss: 2.3526
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.7897 - loss: 0.5902 - val_accuracy: 0.2278 - val_loss: 2.4639
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.8451 - loss: 0.4528 - val_accuracy: 0.2556 - val_loss: 2.5354
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.8492 - loss: 0.4080 - val_accuracy: 0.2667 - val_loss: 2.6802
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 107s 13s/step - accuracy: 0.8908 - loss: 0.3652 - val_accuracy: 0.2000 - val_loss: 3.0790
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.9270 - loss: 0.2767 - val_accuracy: 0.2500 - val_loss: 2.7988
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9443 - loss: 0.2390 - val_accuracy: 0.2667 - val_loss: 2.8441
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.9688 - loss: 0.1844 - val_accuracy: 0.2833 - val_loss: 2.4988
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9725 - loss: 0.1858 - val_accuracy: 0.2722 - val_loss: 2.9233
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 106s 13s/step - accuracy: 0.9552 - loss: 0.2089 - val_accuracy: 0.2556 - val_loss: 3.0794
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 13s/step - accuracy: 0.9844 - loss: 0.1190 - val_accuracy: 0.2556 - val_loss: 2.9010
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9886 - loss: 0.0876 - val_accuracy: 0.3222 - val_loss: 2.4431
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9952 - loss: 0.0667 - val_accuracy: 0.2889 - val_loss: 2.5643
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 13s/step - accuracy: 0.9903 - loss: 0.0734 - val_accuracy: 0.2611 - val_loss: 2.8084
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9922 - loss: 0.0581 - val_accuracy: 0.3000 - val_loss: 2.7556
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9979 - loss: 0.0329 - val_accuracy: 0.2722 - val_loss: 2.8382
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9978 - loss: 0.0263 - val_accuracy: 0.2778 - val_loss: 2.8065
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 0.2833 - val_loss: 2.7430
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.6595 - loss: 1.1909 - val_accuracy: 0.3167 - val_loss: 2.6750
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.7307 - loss: 0.7545 - val_accuracy: 0.3222 - val_loss: 2.2013
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 13s/step - accuracy: 0.7659 - loss: 0.5957 - val_accuracy: 0.3722 - val_loss: 1.9699
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 13s/step - accuracy: 0.8660 - loss: 0.4099 - val_accuracy: 0.3889 - val_loss: 1.8956
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.8651 - loss: 0.3946 - val_accuracy: 0.3278 - val_loss: 2.1647
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.9090 - loss: 0.2965 - val_accuracy: 0.5167 - val_loss: 1.5288
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9429 - loss: 0.2152 - val_accuracy: 0.5000 - val_loss: 1.5801
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.9640 - loss: 0.1506 - val_accuracy: 0.5667 - val_loss: 1.4895
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9887 - loss: 0.0970 - val_accuracy: 0.5167 - val_loss: 1.6230
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9933 - loss: 0.0769 - val_accuracy: 0.5389 - val_loss: 1.5509
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 1.0000 - loss: 0.0487 - val_accuracy: 0.5278 - val_loss: 1.5813
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.9987 - loss: 0.0435 - val_accuracy: 0.5556 - val_loss: 1.5311
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.5167 - val_loss: 1.5926
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.9973 - loss: 0.0307 - val_accuracy: 0.5167 - val_loss: 1.6092
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.5222 - val_loss: 1.5981
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.5389 - val_loss: 1.6219
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.5389 - val_loss: 1.5923
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.5500 - val_loss: 1.5453
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.5667 - val_loss: 1.5583
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.5722 - val_loss: 1.5309
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 104s 13s/step - accuracy: 0.6825 - loss: 1.2580 - val_accuracy: 0.5778 - val_loss: 1.5684
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.7574 - loss: 0.7602 - val_accuracy: 0.5278 - val_loss: 1.8593
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.7767 - loss: 0.5546 - val_accuracy: 0.4278 - val_loss: 2.8119
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 13s/step - accuracy: 0.8701 - loss: 0.3754 - val_accuracy: 0.4833 - val_loss: 2.4441
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.8926 - loss: 0.3268 - val_accuracy: 0.4444 - val_loss: 3.1908
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.9432 - loss: 0.1957 - val_accuracy: 0.5000 - val_loss: 1.9906
# Epoch 7/20
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 6:09 53s/step - accuracy: 0.9900 - loss: 0.0963

# %%
import matplotlib.pyplot as plt

# Plot training history
for history in histories:
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# Calculate final accuracy on test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Final Test Accuracy: {test_accuracy}')
